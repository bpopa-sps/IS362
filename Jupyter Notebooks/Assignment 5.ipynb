# %% [markdown]
# # IS 362 - Week 5 Assignment
#
# ### by Bogdan Popa
#
#
# ##### Assignment:
# Using the raw data from https://github.com/hadley/nycflights13/tree/master/data-raw answer three questions:
# 1. What is the northernmost airport in the United States?
# 2. What is the easternmost airport in the United States?
# 3. On February 12th, 2013, which New York area airport had the windiest weather?
#
#
# To answer the first two questions the airports.csv data file is needed.

# %%
#import pandas
import pandas as pd

#Import data from csv
data = pd.read_csv ('airports.csv')

#Dispaly table
data
# Out:
#       faa                           name        lat         lon   alt  tz dst  \
# 0     04G              Lansdowne Airport  41.130472  -80.619583  1044  -5   A
# 1     06A  Moton Field Municipal Airport  32.460572  -85.680028   264  -6   A
# 2     06C            Schaumburg Regional  41.989341  -88.101243   801  -6   A
# 3     06N                Randall Airport  41.431912  -74.391561   523  -5   A
# 4     09J          Jekyll Island Airport  31.074472  -81.427778    11  -5   A
# ...   ...                            ...        ...         ...   ...  ..  ..
# 1453  ZUN                     Black Rock  35.083228 -108.791778  6454  -7   A
# 1454  ZVE         New Haven Rail Station  41.298669  -72.925992     7  -5   A
# 1455  ZWI      Wilmington Amtrak Station  39.736667  -75.551667     0  -5   A
# 1456  ZWU       Washington Union Station  38.897460  -77.006430    76  -5   A
# 1457  ZYP                   Penn Station  40.750500  -73.993500    35  -5   A
#
#                  tzone
# ...

# %% [markdown]
# ## 1. What is the northernmost airport in the United States?
#
# To determine the northernmost airport, we have to look at the latitude collumn in the data.
# The highest latitude value would be the nothermost airport.

# %%
# To find out the highest value I use a query to filter out the max latitude.
data.query('lat==lat.max()')
# Out:
#      faa                     name        lat        lon  alt  tz dst tzone
# 417  EEN  Dillant Hopkins Airport  72.270833  42.898333  149  -5   A   NaN

# %% [markdown]
# To verify I will list the top 5 northmost airports in the U.S.

# %%
# Get he top 5 largest latitudes from the data.
data.nlargest(5,['lat'])
# Out:
#      faa                                        name        lat         lon  \
# 417  EEN                     Dillant Hopkins Airport  72.270833   42.898333
# 230  BRW                  Wiley Post Will Rogers Mem  71.285446 -156.766003
# 110  AIN                          Wainwright Airport  70.638056 -159.994722
# 708  K03                               Wainwright As  70.613378 -159.860350
# 152  ATK  Atqasuk Edward Burnell Sr Memorial Airport  70.467300 -157.436000
#
#      alt  tz dst              tzone
# 417  149  -5   A                NaN
# 230   44  -9   A  America/Anchorage
# 110   41  -9   A  America/Anchorage
# 708   35  -9   A  America/Anchorage
# 152   96  -9   A  America/Anchorage

# %% [markdown]
# ### Q1 Answer : Dillan Hopkins AIrport*
#
# According to the data the Dillan Hopkins AIrport is the northermost airport in the U.S.
#
# *However, this is not correct. A quick Google search shows that Wiley Post Will Rogers is the northermost airport. It look like the data used for this assignment is not accurate.The Dillant Hopkins Airport entry has the longitude and latitude values switched in this data set.

# %% [markdown]
# ## 2. What is the easternmost airport in the United States?
#
# To find out the easternmost airport we have to look for the airport with the highest longitude value.

# %%
# Finding out the highest longitude by using max()
data.query('lon==lon.max()')
# Out:
#       faa          name        lat        lon  alt  tz dst              tzone
# 1290  SYA  Eareckson As  52.712275  174.11362   98  -9   A  America/Anchorage

# %% [markdown]
# To verify, I will list the top 5 easternmost airports.

# %%
# Listing the 5 largest longitude airports
data.nlargest(5,['lon'])
# Out:
#       faa                           name        lat         lon   alt  tz dst  \
# 1290  SYA                   Eareckson As  52.712275  174.113620    98  -9   A
# 942   MYF               Montgomery Field  32.475900  117.759000    17   8   A
# 396   DVT  Deer Valley Municipal Airport  33.411700  112.457000  1478   8   A
# 417   EEN        Dillant Hopkins Airport  72.270833   42.898333   149  -5   A
# 444   EPM     Eastport Municipal Airport  44.910111  -67.012694    45  -5   A
#
#                   tzone
# 1290  America/Anchorage
# 942      Asia/Chongqing
# 396      Asia/Chongqing
# 417                 NaN
# 444    America/New_York

# %% [markdown]
# ### Q2 Answer : Eareckson Air Station
# According to the data the easternmost airport is the Eareckson Air Station.

# %% [markdown]
# ## 3. On February 12th, 2013, which New York area airport had the windiest weather?
#
# To find out the windiest weather we have to look at the weather.csv dataset and calculate the wind speed average for each NYC airport.

# %%
#Import data from csv
wdata = pd.read_csv ('weather.csv')

#Dispaly table
wdata
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0        EWR  2013      1    1     1  39.02  26.06  59.37     270.0
# 1        EWR  2013      1    1     2  39.02  26.96  61.63     250.0
# 2        EWR  2013      1    1     3  39.02  28.04  64.43     240.0
# 3        EWR  2013      1    1     4  39.92  28.04  62.21     250.0
# 4        EWR  2013      1    1     5  39.02  28.04  64.43     260.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...       ...
# 26110    LGA  2013     12   30    14  35.96  19.94  51.78     340.0
# 26111    LGA  2013     12   30    15  33.98  17.06  49.51     330.0
# 26112    LGA  2013     12   30    16  32.00  15.08  49.19     340.0
# 26113    LGA  2013     12   30    17  30.92  12.92  46.74     320.0
# 26114    LGA  2013     12   30    18  28.94  10.94  46.41     330.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# ...

# %% [markdown]
# Next, I filter the data by origin and select only the information about February 12th, 2013.

# %%
# Creating a new data frame with the EWR data for 2/12/2013
wd_ewr = wdata[(wdata['year']==2013) & (wdata['month']==2) & (wdata['day']==12) & (wdata['origin']=='EWR')]

# LGA Data Frame
wd_lga = wdata[(wdata['year']==2013) & (wdata['month']==2) & (wdata['day']==12) & (wdata['origin']=='LGA')]

# JFK Data Frame
wd_jfk = wdata[(wdata['year']==2013) & (wdata['month']==2) & (wdata['day']==12) & (wdata['origin']=='JFK')]
  
# Extract only the Wind Speed from each data frame
# EWR wind speed
ws_ewr = wd_ewr['wind_speed']

# LGA wind speed
ws_lga = wd_lga['wind_speed']

# JFK wind speed
ws_jfk = wd_jfk['wind_speed']

# %% [markdown]
# #### Dealing with outliners
#
# To remove the outliners, I have decided to trim the lowest and highest quantile from the data.
#
# The wind speed is measured every hour so there are 24 entries for 2/12/2013. Trimming the lowest and highest entry will leave the us with 22 entries.

# %%
# Trimming the lowest and highest quantile for each data frame.
ewr_tr = ws_ewr[ws_ewr.between(ws_ewr.quantile(.01), ws_ewr.quantile(.99))]
lga_tr = ws_lga[ws_lga.between(ws_lga.quantile(.01), ws_lga.quantile(.99))]
jfk_tr = ws_jfk[ws_jfk.between(ws_jfk.quantile(.01), ws_jfk.quantile(.99))]

# %% [markdown]
# To find out which NYC airport was the windies on 2/12/2013 I will calculate and compare the mean of the recorded wind speed.

# %%
print("Wind Speed Mean at EWR:",ewr_tr.mean())
print("Wind Speed Mean at LGA:",lga_tr.mean())
print("Wind Speed Mean at JFK:",jfk_tr.mean())
# Out:
# Wind Speed Mean at EWR: 13.65243545454545
# Wind Speed Mean at LGA: 15.064756363636361
# Wind Speed Mean at JFK: 14.541674545454544

# %% [markdown]
# ### Q3 Answer: LGA
#
# The LGA airport was the windiest airport in NYC on 2/12/2013.
